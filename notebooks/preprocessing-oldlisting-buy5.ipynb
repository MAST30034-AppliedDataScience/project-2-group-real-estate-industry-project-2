# %% [markdown]
# # Preprocessing oldlisting_buy_5

# %%
import sys, os
sys.path.append(os.path.abspath('../'))
from scripts.utils import create_dir, get_runtime
import time 
start_time = time.time()

import pandas as pd
import re
import ast

# %%
# Load your dataset (replace with the correct path to your CSV file)
file_path = "../data/landing/oldlistings_buy/oldlistings_buy_5.csv"
df = pd.read_csv(file_path)

# Helper functions to extract and process data
def expand_rented_prices(row):
    try:
        rent_list = ast.literal_eval(row['rented_prices'])
        rows = []
        for rent in rent_list:
            new_row = row.copy()
            new_row['rented_price'] = rent.get('price', None)
            new_row['date'] = rent.get('date', None)
            rows.append(new_row)
        return pd.DataFrame(rows)
    except (ValueError, SyntaxError):
        return pd.DataFrame([row])

def extract_from_meta_data(meta_data_str, label):
    try:
        meta_list = ast.literal_eval(meta_data_str)
        for item in meta_list:
            if item.get('label') == label:
                return item.get('quantity', None)
    except Exception:
        return None

# Apply the process to expand the first 100 rows (or all rows if needed)
expanded_rows = pd.concat([expand_rented_prices(row) for _, row in df.iterrows()], ignore_index=True)

# Extract meta_data columns for bed, bath, car, land, type
expanded_rows['bed'] = expanded_rows['meta_data'].apply(lambda x: extract_from_meta_data(x, 'bed'))
expanded_rows['bath'] = expanded_rows['meta_data'].apply(lambda x: extract_from_meta_data(x, 'bath'))
expanded_rows['car'] = expanded_rows['meta_data'].apply(lambda x: extract_from_meta_data(x, 'car'))
expanded_rows['land'] = expanded_rows['meta_data'].apply(lambda x: extract_from_meta_data(x, 'land'))
expanded_rows['type'] = expanded_rows['meta_data'].apply(lambda x: extract_from_meta_data(x, 'type'))

# Keep only relevant columns
final_expanded_df = expanded_rows[['lat', 'lng', 'address', 'bed', 'bath', 'car', 'land', 'type', 'rented_price', 'date']]

# Optionally, print or view the dataframe
# print(final_expanded_df)

# %%
# Function to clean rented_prices
final_expanded_df['property_price_cleaned'] = (
    final_expanded_df['rented_price']
    .str.replace(r'\u200b', '', regex=False)           # Remove zero-width space
    .str.replace(r'\xa0', '', regex=False)             # Remove non-breaking space
    .str.replace(r'<span>', '', regex=False)           # Remove <span> tag
    .str.replace(r'</span>', '', regex=False)          # Remove </span> tag
    #.str.translate(translation_table)                 # Convert full-width digits to ASCII digits
    # Convert full-width digits to ASCII digits
    .str.replace('０', '0')
    .str.replace('１', '1')
    .str.replace('２', '2')
    .str.replace('３', '3')
    .str.replace('４', '4')
    .str.replace('５', '5')
    .str.replace('６', '6')
    .str.replace('７', '7')
    .str.replace('８', '8')
    .str.replace('９', '9')
    .str.replace('4', '4')
    .str.replace('𝟻', '5')
    .str.replace('𝟼', '6')
    .str.replace('𝟽', '7')
    .str.replace('𝟾', '8')
    .str.replace('𝟿', '9')
    .str.replace('𝟶', '0')
    .str.replace('𝟹', '3')
    .str.replace('𝟺', '4')
    .str.replace('𝟸', '2')
    .str.replace('𝟷', '1')
    .str.replace('𝟫', '9')
    .str.replace('𝟪', '8')
    .str.replace('𝟩', '7')
    .str.replace('𝟨', '6')
    .str.replace('𝟧', '5')
    .str.replace('𝟦', '4')
    .str.replace('𝟥', '3')
    .str.replace('𝟤', '2')
    .str.replace('𝟣', '1')
    .str.replace('𝟢', '0')
    .str.replace('𝟡', '9')
    .str.replace('𝟠', '8')
    .str.replace('𝟟', '7')
    .str.replace('𝟞', '6')
    .str.replace('𝟝', '5')
    .str.replace('𝟜', '4')
    .str.replace('𝟛', '3')
    .str.replace('𝟚', '2')
    .str.replace('𝟙', '1')
    .str.replace('𝟘', '0')
    .str.replace('𝟗', '9')
    .str.replace('𝟖', '8')
    .str.replace('𝟕', '7')
    .str.replace('𝟔', '6')
    .str.replace('𝟓', '5')
    .str.replace('𝟒', '4')
    .str.replace('𝟑', '3')
    .str.replace('𝟐', '2')
    .str.replace('𝟏', '1')
    .str.replace('𝟎', '0')
    .str.replace('𝟌', '4')
    .str.replace('𝟋', '3')
    .str.replace('𝟊', '2')
    .str.replace('𝟉', '1')
    .str.replace('𝟈', '0')
    .str.replace('𝟇', '9')
    .str.replace('𝟆', '8')
    .str.replace('𝟅', '7')
    .str.replace('𝟄', '6')
    .str.replace('𝟃', '5')
    .str.replace('𝟂', '4')
    .str.replace('𝟁', '3')
    .str.replace('𝟀', '2')
    .str.replace('𝞿', '1')
    .str.replace('𝞾', '0')
)
# Out:
# /tmp/ipykernel_14930/2278130057.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_expanded_df['property_price_cleaned'] = (

# %%
# Replace "O" with "0" in rented_price_cleaned
final_expanded_df['property_price_cleaned'] = final_expanded_df['property_price_cleaned'].str.replace('O', '0')
final_expanded_df
# Out:
# /tmp/ipykernel_14930/825901540.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_expanded_df['property_price_cleaned'] = final_expanded_df['property_price_cleaned'].str.replace('O', '0')
#         lat  lng                            address      bed bath      car  \
# 0       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 1       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 2       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 3       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 4       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# ...     ...  ...                                ...      ...  ...      ...
# 517107  NaN  NaN        63 ALBENCA STREET, MΕNTОNΕ         3    1        𝟷
# 517108  NaN  NaN        63 ALBENCA STREET, MΕNTОNΕ         3    1        𝟷
# 517109  NaN  NaN         13​ 𝙻ОԌΑN СОՍRT , MΕNTОNΕ   \u200b4    𝟸        2
# 517110  NaN  NaN         13​ 𝙻ОԌΑN СОՍRT , MΕNTОNΕ   \u200b4    𝟸        2
# 517111  NaN  NaN  ​3/42 ​FLINDERS STREET​ , MENTONE        𝟸    1        1
#
#         land       type                             rented_price  \
# 0       None       None                                $𝟽OO Week
# 1       None       None                                $750 Week
# 2       None       None                                  Auction
# 3       None       None  $𝟫OO,OOO - $990\u200b,000 A\u200buction
# 4       None       None    \u200b$670,000 In e\u200bxcess ᴏf\xa0
# ...      ...        ...                                      ...
# 517107  None      House                  $6\u200b70,000 \u200b-
# 517108  None      House                      $670,000 - $720,000
# 517109  None      House                               $1,210,000
# 517110  None      House        $1,10\u200b0,000 - $𝟷,𝟸OO,OOO\xa0
# 517111  None  Unit/apmt                                      NaN
#
#                   date       property_price_cleaned
# 0           April 2019                    $700 Week
# 1        December 2017                    $750 Week
# 2         October 2014                      Auction
# 3         October 2014  $900,000 - $990,000 Auction
# 4        November 2007        $670,000 In excess ᴏf
# ...                ...                          ...
# 517107  September 2011                  $670,000 -
# 517108     August 2011          $670,000 - $720,000
# 517109   February 2018                   $1,210,000
# 517110   February 2018      $1,100,000 - $1,200,000
# 517111             NaN                          NaN
#
# [517112 rows x 11 columns]

# %%
# Replace all non-numeric characters with NaN from rented_price_cleaned except for commas and "$" signs and "-" signs
final_expanded_df['property_price_cleaned'] = final_expanded_df['property_price_cleaned'].str.replace(r'[^0-9,$-]', '', regex=True)
final_expanded_df
# Out:
# /tmp/ipykernel_14930/3598943794.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_expanded_df['property_price_cleaned'] = final_expanded_df['property_price_cleaned'].str.replace(r'[^0-9,$-]', '', regex=True)
#         lat  lng                            address      bed bath      car  \
# 0       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 1       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 2       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 3       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 4       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# ...     ...  ...                                ...      ...  ...      ...
# 517107  NaN  NaN        63 ALBENCA STREET, MΕNTОNΕ         3    1        𝟷
# 517108  NaN  NaN        63 ALBENCA STREET, MΕNTОNΕ         3    1        𝟷
# 517109  NaN  NaN         13​ 𝙻ОԌΑN СОՍRT , MΕNTОNΕ   \u200b4    𝟸        2
# 517110  NaN  NaN         13​ 𝙻ОԌΑN СОՍRT , MΕNTОNΕ   \u200b4    𝟸        2
# 517111  NaN  NaN  ​3/42 ​FLINDERS STREET​ , MENTONE        𝟸    1        1
#
#         land       type                             rented_price  \
# 0       None       None                                $𝟽OO Week
# 1       None       None                                $750 Week
# 2       None       None                                  Auction
# 3       None       None  $𝟫OO,OOO - $990\u200b,000 A\u200buction
# 4       None       None    \u200b$670,000 In e\u200bxcess ᴏf\xa0
# ...      ...        ...                                      ...
# 517107  None      House                  $6\u200b70,000 \u200b-
# 517108  None      House                      $670,000 - $720,000
# 517109  None      House                               $1,210,000
# 517110  None      House        $1,10\u200b0,000 - $𝟷,𝟸OO,OOO\xa0
# 517111  None  Unit/apmt                                      NaN
#
#                   date property_price_cleaned
# 0           April 2019                   $700
# 1        December 2017                   $750
# 2         October 2014
# 3         October 2014      $900,000-$990,000
# 4        November 2007               $670,000
# ...                ...                    ...
# 517107  September 2011              $670,000-
# 517108     August 2011      $670,000-$720,000
# 517109   February 2018             $1,210,000
# 517110   February 2018  $1,100,000-$1,200,000
# 517111             NaN                    NaN
#
# [517112 rows x 11 columns]

# %%
# Function to clean and handle range prices by calculating the average
def clean_price(price):
    if pd.isna(price):
        return price  # Return NaN as is
    # Handle price ranges like "$425,000-$455,000"
    range_match = re.match(r"\$(\d+,\d+)-\$(\d+,\d+)", price)
    if range_match:
        low_price = int(range_match.group(1).replace(',', ''))
        high_price = int(range_match.group(2).replace(',', ''))
        return (low_price + high_price) / 2  # Return the average of the range
    # Handle normal prices
    price_cleaned = re.sub(r'[^\d]', '', price)
    return int(price_cleaned) if price_cleaned.isdigit() else None

# %%
final_expanded_df['property_price_cleaned'] = [clean_price(price) for price in final_expanded_df['property_price_cleaned']]

final_expanded_df
# Out:
# /tmp/ipykernel_14930/2455915571.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_expanded_df['property_price_cleaned'] = [clean_price(price) for price in final_expanded_df['property_price_cleaned']]
#         lat  lng                            address      bed bath      car  \
# 0       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 1       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 2       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 3       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 4       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# ...     ...  ...                                ...      ...  ...      ...
# 517107  NaN  NaN        63 ALBENCA STREET, MΕNTОNΕ         3    1        𝟷
# 517108  NaN  NaN        63 ALBENCA STREET, MΕNTОNΕ         3    1        𝟷
# 517109  NaN  NaN         13​ 𝙻ОԌΑN СОՍRT , MΕNTОNΕ   \u200b4    𝟸        2
# 517110  NaN  NaN         13​ 𝙻ОԌΑN СОՍRT , MΕNTОNΕ   \u200b4    𝟸        2
# 517111  NaN  NaN  ​3/42 ​FLINDERS STREET​ , MENTONE        𝟸    1        1
#
#         land       type                             rented_price  \
# 0       None       None                                $𝟽OO Week
# 1       None       None                                $750 Week
# 2       None       None                                  Auction
# 3       None       None  $𝟫OO,OOO - $990\u200b,000 A\u200buction
# 4       None       None    \u200b$670,000 In e\u200bxcess ᴏf\xa0
# ...      ...        ...                                      ...
# 517107  None      House                  $6\u200b70,000 \u200b-
# 517108  None      House                      $670,000 - $720,000
# 517109  None      House                               $1,210,000
# 517110  None      House        $1,10\u200b0,000 - $𝟷,𝟸OO,OOO\xa0
# 517111  None  Unit/apmt                                      NaN
#
#                   date  property_price_cleaned
# 0           April 2019            7.000000e+02
# 1        December 2017            7.500000e+02
# 2         October 2014                     NaN
# 3         October 2014            9.450000e+05
# 4        November 2007            6.700000e+05
# ...                ...                     ...
# 517107  September 2011            6.700000e+05
# 517108     August 2011            6.950000e+05
# 517109   February 2018            1.210000e+06
# 517110   February 2018            1.100000e+13
# 517111             NaN                     NaN
#
# [517112 rows x 11 columns]

# %%
final_expanded_df['date'] = pd.to_datetime(final_expanded_df['date'], errors='coerce')
final_expanded_df
# Out:
# /tmp/ipykernel_14930/1390822886.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   final_expanded_df['date'] = pd.to_datetime(final_expanded_df['date'], errors='coerce')
# /tmp/ipykernel_14930/1390822886.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_expanded_df['date'] = pd.to_datetime(final_expanded_df['date'], errors='coerce')
#         lat  lng                            address      bed bath      car  \
# 0       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 1       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 2       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 3       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 4       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# ...     ...  ...                                ...      ...  ...      ...
# 517107  NaN  NaN        63 ALBENCA STREET, MΕNTОNΕ         3    1        𝟷
# 517108  NaN  NaN        63 ALBENCA STREET, MΕNTОNΕ         3    1        𝟷
# 517109  NaN  NaN         13​ 𝙻ОԌΑN СОՍRT , MΕNTОNΕ   \u200b4    𝟸        2
# 517110  NaN  NaN         13​ 𝙻ОԌΑN СОՍRT , MΕNTОNΕ   \u200b4    𝟸        2
# 517111  NaN  NaN  ​3/42 ​FLINDERS STREET​ , MENTONE        𝟸    1        1
#
#         land       type                             rented_price       date  \
# 0       None       None                                $𝟽OO Week 2019-04-01
# 1       None       None                                $750 Week 2017-12-01
# 2       None       None                                  Auction 2014-10-01
# 3       None       None  $𝟫OO,OOO - $990\u200b,000 A\u200buction 2014-10-01
# 4       None       None    \u200b$670,000 In e\u200bxcess ᴏf\xa0 2007-11-01
# ...      ...        ...                                      ...        ...
# 517107  None      House                  $6\u200b70,000 \u200b-  2011-09-01
# 517108  None      House                      $670,000 - $720,000 2011-08-01
# 517109  None      House                               $1,210,000 2018-02-01
# 517110  None      House        $1,10\u200b0,000 - $𝟷,𝟸OO,OOO\xa0 2018-02-01
# 517111  None  Unit/apmt                                      NaN        NaT
#
#         property_price_cleaned
# 0                 7.000000e+02
# 1                 7.500000e+02
# 2                          NaN
# 3                 9.450000e+05
# 4                 6.700000e+05
# ...                        ...
# 517107            6.700000e+05
# 517108            6.950000e+05
# 517109            1.210000e+06
# 517110            1.100000e+13
# 517111                     NaN
#
# [517112 rows x 11 columns]

# %%
# Function to clean "bed"
final_expanded_df['bed_cleaned'] = (
    final_expanded_df['bed']
    .str.replace(r'\u200b', '', regex=False)           # Remove zero-width space
    .str.replace(r'\xa0', '', regex=False)             # Remove non-breaking space
    .str.replace(r'<span>', '', regex=False)           # Remove <span> tag
    .str.replace(r'</span>', '', regex=False)          # Remove </span> tag
    #.str.translate(translation_table)                 # Convert full-width digits to ASCII digits
    # Convert full-width digits to ASCII digits
    .str.replace('０', '0')
    .str.replace('１', '1')
    .str.replace('２', '2')
    .str.replace('３', '3')
    .str.replace('４', '4')
    .str.replace('５', '5')
    .str.replace('６', '6')
    .str.replace('７', '7')
    .str.replace('８', '8')
    .str.replace('９', '9')
    .str.replace('4', '4')
    .str.replace('𝟻', '5')
    .str.replace('𝟼', '6')
    .str.replace('𝟽', '7')
    .str.replace('𝟾', '8')
    .str.replace('𝟿', '9')
    .str.replace('𝟶', '0')
    .str.replace('𝟹', '3')
    .str.replace('𝟺', '4')
    .str.replace('𝟸', '2')
    .str.replace('𝟷', '1')
    .str.replace('𝟫', '9')
    .str.replace('𝟪', '8')
    .str.replace('𝟩', '7')
    .str.replace('𝟨', '6')
    .str.replace('𝟧', '5')
    .str.replace('𝟦', '4')
    .str.replace('𝟥', '3')
    .str.replace('𝟤', '2')
    .str.replace('𝟣', '1')
    .str.replace('𝟢', '0')
    .str.replace('𝟡', '9')
    .str.replace('𝟠', '8')
    .str.replace('𝟟', '7')
    .str.replace('𝟞', '6')
    .str.replace('𝟝', '5')
    .str.replace('𝟜', '4')
    .str.replace('𝟛', '3')
    .str.replace('𝟚', '2')
    .str.replace('𝟙', '1')
    .str.replace('𝟘', '0')
    .str.replace('𝟗', '9')
    .str.replace('𝟖', '8')
    .str.replace('𝟕', '7')
    .str.replace('𝟔', '6')
    .str.replace('𝟓', '5')
    .str.replace('𝟒', '4')
    .str.replace('𝟑', '3')
    .str.replace('𝟐', '2')
    .str.replace('𝟏', '1')
    .str.replace('𝟎', '0')
    .str.replace('𝟌', '4')
    .str.replace('𝟋', '3')
    .str.replace('𝟊', '2')
    .str.replace('𝟉', '1')
    .str.replace('𝟈', '0')
    .str.replace('𝟇', '9')
    .str.replace('𝟆', '8')
    .str.replace('𝟅', '7')
    .str.replace('𝟄', '6')
    .str.replace('𝟃', '5')
    .str.replace('𝟂', '4')
    .str.replace('𝟁', '3')
    .str.replace('𝟀', '2')
    .str.replace('𝞿', '1')
    .str.replace('𝞾', '0')
)
# Out:
# /tmp/ipykernel_14930/2184586359.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_expanded_df['bed_cleaned'] = (

# %%
# Function to clean "bath"
final_expanded_df['bath_cleaned'] = (
    final_expanded_df['bath']
    .str.replace(r'\u200b', '', regex=False)           # Remove zero-width space
    .str.replace(r'\xa0', '', regex=False)             # Remove non-breaking space
    .str.replace(r'<span>', '', regex=False)           # Remove <span> tag
    .str.replace(r'</span>', '', regex=False)          # Remove </span> tag
    #.str.translate(translation_table)                 # Convert full-width digits to ASCII digits
    # Convert full-width digits to ASCII digits
    .str.replace('０', '0')
    .str.replace('１', '1')
    .str.replace('２', '2')
    .str.replace('３', '3')
    .str.replace('４', '4')
    .str.replace('５', '5')
    .str.replace('６', '6')
    .str.replace('７', '7')
    .str.replace('８', '8')
    .str.replace('９', '9')
    .str.replace('4', '4')
    .str.replace('𝟻', '5')
    .str.replace('𝟼', '6')
    .str.replace('𝟽', '7')
    .str.replace('𝟾', '8')
    .str.replace('𝟿', '9')
    .str.replace('𝟶', '0')
    .str.replace('𝟹', '3')
    .str.replace('𝟺', '4')
    .str.replace('𝟸', '2')
    .str.replace('𝟷', '1')
    .str.replace('𝟫', '9')
    .str.replace('𝟪', '8')
    .str.replace('𝟩', '7')
    .str.replace('𝟨', '6')
    .str.replace('𝟧', '5')
    .str.replace('𝟦', '4')
    .str.replace('𝟥', '3')
    .str.replace('𝟤', '2')
    .str.replace('𝟣', '1')
    .str.replace('𝟢', '0')
    .str.replace('𝟡', '9')
    .str.replace('𝟠', '8')
    .str.replace('𝟟', '7')
    .str.replace('𝟞', '6')
    .str.replace('𝟝', '5')
    .str.replace('𝟜', '4')
    .str.replace('𝟛', '3')
    .str.replace('𝟚', '2')
    .str.replace('𝟙', '1')
    .str.replace('𝟘', '0')
    .str.replace('𝟗', '9')
    .str.replace('𝟖', '8')
    .str.replace('𝟕', '7')
    .str.replace('𝟔', '6')
    .str.replace('𝟓', '5')
    .str.replace('𝟒', '4')
    .str.replace('𝟑', '3')
    .str.replace('𝟐', '2')
    .str.replace('𝟏', '1')
    .str.replace('𝟎', '0')
    .str.replace('𝟌', '4')
    .str.replace('𝟋', '3')
    .str.replace('𝟊', '2')
    .str.replace('𝟉', '1')
    .str.replace('𝟈', '0')
    .str.replace('𝟇', '9')
    .str.replace('𝟆', '8')
    .str.replace('𝟅', '7')
    .str.replace('𝟄', '6')
    .str.replace('𝟃', '5')
    .str.replace('𝟂', '4')
    .str.replace('𝟁', '3')
    .str.replace('𝟀', '2')
    .str.replace('𝞿', '1')
    .str.replace('𝞾', '0')
)

# %%
# Function to clean "car"
final_expanded_df['car_cleaned'] = (
    final_expanded_df['car']
    .str.replace(r'\u200b', '', regex=False)           # Remove zero-width space
    .str.replace(r'\xa0', '', regex=False)             # Remove non-breaking space
    .str.replace(r'<span>', '', regex=False)           # Remove <span> tag
    .str.replace(r'</span>', '', regex=False)          # Remove </span> tag
    #.str.translate(translation_table)                 # Convert full-width digits to ASCII digits
    # Convert full-width digits to ASCII digits
    .str.replace('０', '0')
    .str.replace('１', '1')
    .str.replace('２', '2')
    .str.replace('３', '3')
    .str.replace('４', '4')
    .str.replace('５', '5')
    .str.replace('６', '6')
    .str.replace('７', '7')
    .str.replace('８', '8')
    .str.replace('９', '9')
    .str.replace('4', '4')
    .str.replace('𝟻', '5')
    .str.replace('𝟼', '6')
    .str.replace('𝟽', '7')
    .str.replace('𝟾', '8')
    .str.replace('𝟿', '9')
    .str.replace('𝟶', '0')
    .str.replace('𝟹', '3')
    .str.replace('𝟺', '4')
    .str.replace('𝟸', '2')
    .str.replace('𝟷', '1')
    .str.replace('𝟫', '9')
    .str.replace('𝟪', '8')
    .str.replace('𝟩', '7')
    .str.replace('𝟨', '6')
    .str.replace('𝟧', '5')
    .str.replace('𝟦', '4')
    .str.replace('𝟥', '3')
    .str.replace('𝟤', '2')
    .str.replace('𝟣', '1')
    .str.replace('𝟢', '0')
    .str.replace('𝟡', '9')
    .str.replace('𝟠', '8')
    .str.replace('𝟟', '7')
    .str.replace('𝟞', '6')
    .str.replace('𝟝', '5')
    .str.replace('𝟜', '4')
    .str.replace('𝟛', '3')
    .str.replace('𝟚', '2')
    .str.replace('𝟙', '1')
    .str.replace('𝟘', '0')
    .str.replace('𝟗', '9')
    .str.replace('𝟖', '8')
    .str.replace('𝟕', '7')
    .str.replace('𝟔', '6')
    .str.replace('𝟓', '5')
    .str.replace('𝟒', '4')
    .str.replace('𝟑', '3')
    .str.replace('𝟐', '2')
    .str.replace('𝟏', '1')
    .str.replace('𝟎', '0')
    .str.replace('𝟌', '4')
    .str.replace('𝟋', '3')
    .str.replace('𝟊', '2')
    .str.replace('𝟉', '1')
    .str.replace('𝟈', '0')
    .str.replace('𝟇', '9')
    .str.replace('𝟆', '8')
    .str.replace('𝟅', '7')
    .str.replace('𝟄', '6')
    .str.replace('𝟃', '5')
    .str.replace('𝟂', '4')
    .str.replace('𝟁', '3')
    .str.replace('𝟀', '2')
    .str.replace('𝞿', '1')
    .str.replace('𝞾', '0')
)

# %%
# Function to clean "land"
final_expanded_df['land_cleaned'] = (
    final_expanded_df['land']
    .str.replace(r'm2', '', regex=False)           # Remove "m2" unit
    .str.replace(r'\u200b', '', regex=False)           # Remove zero-width space
    .str.replace(r'\xa0', '', regex=False)             # Remove non-breaking space
    .str.replace(r'<span>', '', regex=False)           # Remove <span> tag
    .str.replace(r'</span>', '', regex=False)          # Remove </span> tag
    #.str.translate(translation_table)                 # Convert full-width digits to ASCII digits
    # Convert full-width digits to ASCII digits
    .str.replace('０', '0')
    .str.replace('１', '1')
    .str.replace('２', '2')
    .str.replace('３', '3')
    .str.replace('４', '4')
    .str.replace('５', '5')
    .str.replace('６', '6')
    .str.replace('７', '7')
    .str.replace('８', '8')
    .str.replace('９', '9')
    .str.replace('4', '4')
    .str.replace('𝟻', '5')
    .str.replace('𝟼', '6')
    .str.replace('𝟽', '7')
    .str.replace('𝟾', '8')
    .str.replace('𝟿', '9')
    .str.replace('𝟶', '0')
    .str.replace('𝟹', '3')
    .str.replace('𝟺', '4')
    .str.replace('𝟸', '2')
    .str.replace('𝟷', '1')
    .str.replace('𝟫', '9')
    .str.replace('𝟪', '8')
    .str.replace('𝟩', '7')
    .str.replace('𝟨', '6')
    .str.replace('𝟧', '5')
    .str.replace('𝟦', '4')
    .str.replace('𝟥', '3')
    .str.replace('𝟤', '2')
    .str.replace('𝟣', '1')
    .str.replace('𝟢', '0')
    .str.replace('𝟡', '9')
    .str.replace('𝟠', '8')
    .str.replace('𝟟', '7')
    .str.replace('𝟞', '6')
    .str.replace('𝟝', '5')
    .str.replace('𝟜', '4')
    .str.replace('𝟛', '3')
    .str.replace('𝟚', '2')
    .str.replace('𝟙', '1')
    .str.replace('𝟘', '0')
    .str.replace('𝟗', '9')
    .str.replace('𝟖', '8')
    .str.replace('𝟕', '7')
    .str.replace('𝟔', '6')
    .str.replace('𝟓', '5')
    .str.replace('𝟒', '4')
    .str.replace('𝟑', '3')
    .str.replace('𝟐', '2')
    .str.replace('𝟏', '1')
    .str.replace('𝟎', '0')
    .str.replace('𝟌', '4')
    .str.replace('𝟋', '3')
    .str.replace('𝟊', '2')
    .str.replace('𝟉', '1')
    .str.replace('𝟈', '0')
    .str.replace('𝟇', '9')
    .str.replace('𝟆', '8')
    .str.replace('𝟅', '7')
    .str.replace('𝟄', '6')
    .str.replace('𝟃', '5')
    .str.replace('𝟂', '4')
    .str.replace('𝟁', '3')
    .str.replace('𝟀', '2')
    .str.replace('𝞿', '1')
    .str.replace('𝞾', '0')
)

# %%
final_expanded_df
# Out:
#         lat  lng                            address      bed bath      car  \
# 0       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 1       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 2       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 3       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 4       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# ...     ...  ...                                ...      ...  ...      ...
# 517107  NaN  NaN        63 ALBENCA STREET, MΕNTОNΕ         3    1        𝟷
# 517108  NaN  NaN        63 ALBENCA STREET, MΕNTОNΕ         3    1        𝟷
# 517109  NaN  NaN         13​ 𝙻ОԌΑN СОՍRT , MΕNTОNΕ   \u200b4    𝟸        2
# 517110  NaN  NaN         13​ 𝙻ОԌΑN СОՍRT , MΕNTОNΕ   \u200b4    𝟸        2
# 517111  NaN  NaN  ​3/42 ​FLINDERS STREET​ , MENTONE        𝟸    1        1
#
#         land       type                             rented_price       date  \
# 0       None       None                                $𝟽OO Week 2019-04-01
# 1       None       None                                $750 Week 2017-12-01
# 2       None       None                                  Auction 2014-10-01
# 3       None       None  $𝟫OO,OOO - $990\u200b,000 A\u200buction 2014-10-01
# 4       None       None    \u200b$670,000 In e\u200bxcess ᴏf\xa0 2007-11-01
# ...      ...        ...                                      ...        ...
# 517107  None      House                  $6\u200b70,000 \u200b-  2011-09-01
# 517108  None      House                      $670,000 - $720,000 2011-08-01
# 517109  None      House                               $1,210,000 2018-02-01
# 517110  None      House        $1,10\u200b0,000 - $𝟷,𝟸OO,OOO\xa0 2018-02-01
# 517111  None  Unit/apmt                                      NaN        NaT
#
#         property_price_cleaned bed_cleaned bath_cleaned car_cleaned  \
# 0                 7.000000e+02           4            1           2
# 1                 7.500000e+02           4            1           2
# 2                          NaN           4            1           2
# 3                 9.450000e+05           4            1           2
# 4                 6.700000e+05           4            1           2
# ...                        ...         ...          ...         ...
# 517107            6.700000e+05           3            1           1
# 517108            6.950000e+05           3            1           1
# 517109            1.210000e+06           4            2           2
# 517110            1.100000e+13           4            2           2
# 517111                     NaN           2            1           1
#
#        land_cleaned
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# ...             ...
# 517107         None
# 517108         None
# 517109         None
# 517110         None
# 517111         None
#
# [517112 rows x 15 columns]

# %%
# Function to clean "address"
final_expanded_df['address_cleaned'] = (
    final_expanded_df['address']
    .str.replace(r'\u200b', '', regex=False)           # Remove zero-width space
    .str.replace(r'\xa0', '', regex=False)             # Remove non-breaking space
    .str.replace(r'<span>', '', regex=False)           # Remove <span> tag
    .str.replace(r'</span>', '', regex=False)          # Remove </span> tag
    .str.replace('𝙻', 'L')
    .str.replace('𝙺', 'K')
    .str.replace('𝙹', 'J')
    .str.replace('𝙸', 'I')
    .str.replace('𝙷', 'H')
    .str.replace('𝙶', 'G')
    .str.replace('𝙵', 'F')
    .str.replace('𝙴', 'E')
    .str.replace('𝙳', 'D')
    .str.replace('𝙲', 'C')
    .str.replace('𝙱', 'B')
    .str.replace('𝙰', 'A')
    .str.replace('𝘾', 'C')
    .str.replace('𝘽', 'B')
    .str.replace('𝘼', 'A')
    .str.replace('𝘿', 'D')
    .str.replace('𝘾', 'C')
    .str.replace('𝘽', 'B')
    .str.replace('𝘼', 'A')
    .str.replace('𝘻', 'z')
    .str.replace('𝘺', 'y')
    .str.replace('𝘹', 'x')
    .str.replace('𝘸', 'w')
    .str.replace('𝘷', 'v')
    .str.replace('𝘶', 'u')
    .str.replace('𝘵', 't')
    .str.replace('𝘴', 's')

)

# %%
# Function to clean "address"
final_expanded_df['address_cleaned'] = (
    final_expanded_df['address_cleaned']
    .str.replace('𝘳', 'r')
    .str.replace('𝘲', 'q')
    .str.replace('𝘱', 'p')
    .str.replace('𝘰', 'o')
    .str.replace('𝘯', 'n')
    .str.replace('𝘭', 'l')
    .str.replace('𝘬', 'k')
    .str.replace('𝘫', 'j')
    .str.replace('𝘪', 'i')
    .str.replace('𝘩', 'h')
    .str.replace('𝘨', 'g')
    .str.replace('𝘧', 'f')
    .str.replace('𝘦', 'e')
    .str.replace('𝘥', 'd')
    .str.replace('𝘣', 'b')
    .str.replace('𝘢', 'a')
    .str.replace('𝘡', 'Z')
    .str.replace('𝘠', 'Y')
    .str.replace('𝘟', 'X')
    .str.replace('０', '0')
    .str.replace('１', '1')
    .str.replace('２', '2')
    .str.replace('３', '3')
    .str.replace('４', '4')
    .str.replace('５', '5')
    .str.replace('６', '6')
    .str.replace('７', '7')
    .str.replace('８', '8')
    .str.replace('９', '9')
    .str.replace('4', '4')
    .str.replace('𝟻', '5')
    .str.replace('𝟼', '6')
    .str.replace('𝟽', '7')
    .str.replace('𝟾', '8')
    .str.replace('𝟿', '9')
    .str.replace('𝟶', '0')
    .str.replace('𝟹', '3')
    .str.replace('𝟺', '4')
    .str.replace('𝟸', '2')
    .str.replace('𝟷', '1')
    .str.replace('𝟫', '9')
    .str.replace('𝟪', '8')
    .str.replace('𝟩', '7')
    .str.replace('𝟨', '6')
    .str.replace('𝟧', '5')
    .str.replace('𝟦', '4')
    .str.replace('𝟥', '3')
    .str.replace('𝟤', '2')
    .str.replace('𝟣', '1')
    .str.replace('𝟢', '0')
    .str.replace('𝟡', '9')
    .str.replace('𝟠', '8')
    .str.replace('𝟟', '7')
    .str.replace('𝟞', '6')
    .str.replace('𝟝', '5')
    .str.replace('𝟜', '4')
    .str.replace('𝟛', '3')
    .str.replace('𝟚', '2')
    .str.replace('𝟙', '1')
    .str.replace('𝟘', '0')
    .str.replace('𝟗', '9')
    .str.replace('𝟖', '8')
    .str.replace('𝟕', '7')
    .str.replace('𝟔', '6')
    .str.replace('𝟓', '5')
    .str.replace('𝟒', '4')
    .str.replace('𝟑', '3')
    .str.replace('𝟐', '2')
    .str.replace('𝟏', '1')
    .str.replace('𝟎', '0')
    

)

# %%
final_expanded_df
# Out:
#         lat  lng                            address      bed bath      car  \
# 0       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 1       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 2       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 3       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# 4       NaN  NaN      3𝟫 FILS​ON STRΕΕT, ASCOT VALE        4    1  \u200b2
# ...     ...  ...                                ...      ...  ...      ...
# 517107  NaN  NaN        63 ALBENCA STREET, MΕNTОNΕ         3    1        𝟷
# 517108  NaN  NaN        63 ALBENCA STREET, MΕNTОNΕ         3    1        𝟷
# 517109  NaN  NaN         13​ 𝙻ОԌΑN СОՍRT , MΕNTОNΕ   \u200b4    𝟸        2
# 517110  NaN  NaN         13​ 𝙻ОԌΑN СОՍRT , MΕNTОNΕ   \u200b4    𝟸        2
# 517111  NaN  NaN  ​3/42 ​FLINDERS STREET​ , MENTONE        𝟸    1        1
#
#         land       type                             rented_price       date  \
# 0       None       None                                $𝟽OO Week 2019-04-01
# 1       None       None                                $750 Week 2017-12-01
# 2       None       None                                  Auction 2014-10-01
# 3       None       None  $𝟫OO,OOO - $990\u200b,000 A\u200buction 2014-10-01
# 4       None       None    \u200b$670,000 In e\u200bxcess ᴏf\xa0 2007-11-01
# ...      ...        ...                                      ...        ...
# 517107  None      House                  $6\u200b70,000 \u200b-  2011-09-01
# 517108  None      House                      $670,000 - $720,000 2011-08-01
# 517109  None      House                               $1,210,000 2018-02-01
# 517110  None      House        $1,10\u200b0,000 - $𝟷,𝟸OO,OOO\xa0 2018-02-01
# 517111  None  Unit/apmt                                      NaN        NaT
#
#         property_price_cleaned bed_cleaned bath_cleaned car_cleaned  \
# 0                 7.000000e+02           4            1           2
# 1                 7.500000e+02           4            1           2
# 2                          NaN           4            1           2
# 3                 9.450000e+05           4            1           2
# 4                 6.700000e+05           4            1           2
# ...                        ...         ...          ...         ...
# 517107            6.700000e+05           3            1           1
# 517108            6.950000e+05           3            1           1
# 517109            1.210000e+06           4            2           2
# 517110            1.100000e+13           4            2           2
# 517111                     NaN           2            1           1
#
#        land_cleaned                    address_cleaned
# 0              None      39 FILS​ON STRΕΕT, ASCOT VALE
# 1              None      39 FILS​ON STRΕΕT, ASCOT VALE
# 2              None      39 FILS​ON STRΕΕT, ASCOT VALE
# 3              None      39 FILS​ON STRΕΕT, ASCOT VALE
# 4              None      39 FILS​ON STRΕΕT, ASCOT VALE
# ...             ...                                ...
# 517107         None        63 ALBENCA STREET, MΕNTОNΕ
# 517108         None        63 ALBENCA STREET, MΕNTОNΕ
# 517109         None         13​ LОԌΑN СОՍRT , MΕNTОNΕ
# 517110         None         13​ LОԌΑN СОՍRT , MΕNTОNΕ
# 517111         None  ​3/42 ​FLINDERS STREET​ , MENTONE
#
# [517112 rows x 16 columns]

# %%
# drop some columns
final_expanded_df = final_expanded_df.drop(columns=['rented_price', 'bed', 'bath', 'car', 'land', 'address'])
final_expanded_df
# Out:
#         lat  lng       type       date  property_price_cleaned bed_cleaned  \
# 0       NaN  NaN       None 2019-04-01            7.000000e+02           4
# 1       NaN  NaN       None 2017-12-01            7.500000e+02           4
# 2       NaN  NaN       None 2014-10-01                     NaN           4
# 3       NaN  NaN       None 2014-10-01            9.450000e+05           4
# 4       NaN  NaN       None 2007-11-01            6.700000e+05           4
# ...     ...  ...        ...        ...                     ...         ...
# 517107  NaN  NaN      House 2011-09-01            6.700000e+05           3
# 517108  NaN  NaN      House 2011-08-01            6.950000e+05           3
# 517109  NaN  NaN      House 2018-02-01            1.210000e+06           4
# 517110  NaN  NaN      House 2018-02-01            1.100000e+13           4
# 517111  NaN  NaN  Unit/apmt        NaT                     NaN           2
#
#        bath_cleaned car_cleaned land_cleaned  \
# 0                 1           2         None
# 1                 1           2         None
# 2                 1           2         None
# 3                 1           2         None
# 4                 1           2         None
# ...             ...         ...          ...
# 517107            1           1         None
# 517108            1           1         None
# 517109            2           2         None
# 517110            2           2         None
# 517111            1           1         None
#
#                           address_cleaned
# 0           39 FILS​ON STRΕΕT, ASCOT VALE
# 1           39 FILS​ON STRΕΕT, ASCOT VALE
# 2           39 FILS​ON STRΕΕT, ASCOT VALE
# 3           39 FILS​ON STRΕΕT, ASCOT VALE
# 4           39 FILS​ON STRΕΕT, ASCOT VALE
# ...                                   ...
# 517107        63 ALBENCA STREET, MΕNTОNΕ
# 517108        63 ALBENCA STREET, MΕNTОNΕ
# 517109         13​ LОԌΑN СОՍRT , MΕNTОNΕ
# 517110         13​ LОԌΑN СОՍRT , MΕNTОNΕ
# 517111  ​3/42 ​FLINDERS STREET​ , MENTONE
#
# [517112 rows x 10 columns]

# %%
# Extract year from date
final_expanded_df['year'] = final_expanded_df['date'].dt.year
final_expanded_df
# Out:
#         lat  lng       type       date  property_price_cleaned bed_cleaned  \
# 0       NaN  NaN       None 2019-04-01            7.000000e+02           4
# 1       NaN  NaN       None 2017-12-01            7.500000e+02           4
# 2       NaN  NaN       None 2014-10-01                     NaN           4
# 3       NaN  NaN       None 2014-10-01            9.450000e+05           4
# 4       NaN  NaN       None 2007-11-01            6.700000e+05           4
# ...     ...  ...        ...        ...                     ...         ...
# 517107  NaN  NaN      House 2011-09-01            6.700000e+05           3
# 517108  NaN  NaN      House 2011-08-01            6.950000e+05           3
# 517109  NaN  NaN      House 2018-02-01            1.210000e+06           4
# 517110  NaN  NaN      House 2018-02-01            1.100000e+13           4
# 517111  NaN  NaN  Unit/apmt        NaT                     NaN           2
#
#        bath_cleaned car_cleaned land_cleaned  \
# 0                 1           2         None
# 1                 1           2         None
# 2                 1           2         None
# 3                 1           2         None
# 4                 1           2         None
# ...             ...         ...          ...
# 517107            1           1         None
# 517108            1           1         None
# 517109            2           2         None
# 517110            2           2         None
# 517111            1           1         None
#
#                           address_cleaned    year
# 0           39 FILS​ON STRΕΕT, ASCOT VALE  2019.0
# 1           39 FILS​ON STRΕΕT, ASCOT VALE  2017.0
# 2           39 FILS​ON STRΕΕT, ASCOT VALE  2014.0
# 3           39 FILS​ON STRΕΕT, ASCOT VALE  2014.0
# 4           39 FILS​ON STRΕΕT, ASCOT VALE  2007.0
# ...                                   ...     ...
# 517107        63 ALBENCA STREET, MΕNTОNΕ   2011.0
# 517108        63 ALBENCA STREET, MΕNTОNΕ   2011.0
# 517109         13​ LОԌΑN СОՍRT , MΕNTОNΕ   2018.0
# 517110         13​ LОԌΑN СОՍRT , MΕNTОNΕ   2018.0
# 517111  ​3/42 ​FLINDERS STREET​ , MENTONE     NaN
#
# [517112 rows x 11 columns]

# %%
# Extract suburb from address_cleaned, which is all text after the last comma
final_expanded_df['suburb'] = final_expanded_df['address_cleaned'].str.rsplit(',').str[-1]
final_expanded_df
# Out:
#         lat  lng       type       date  property_price_cleaned bed_cleaned  \
# 0       NaN  NaN       None 2019-04-01            7.000000e+02           4
# 1       NaN  NaN       None 2017-12-01            7.500000e+02           4
# 2       NaN  NaN       None 2014-10-01                     NaN           4
# 3       NaN  NaN       None 2014-10-01            9.450000e+05           4
# 4       NaN  NaN       None 2007-11-01            6.700000e+05           4
# ...     ...  ...        ...        ...                     ...         ...
# 517107  NaN  NaN      House 2011-09-01            6.700000e+05           3
# 517108  NaN  NaN      House 2011-08-01            6.950000e+05           3
# 517109  NaN  NaN      House 2018-02-01            1.210000e+06           4
# 517110  NaN  NaN      House 2018-02-01            1.100000e+13           4
# 517111  NaN  NaN  Unit/apmt        NaT                     NaN           2
#
#        bath_cleaned car_cleaned land_cleaned  \
# 0                 1           2         None
# 1                 1           2         None
# 2                 1           2         None
# 3                 1           2         None
# 4                 1           2         None
# ...             ...         ...          ...
# 517107            1           1         None
# 517108            1           1         None
# 517109            2           2         None
# 517110            2           2         None
# 517111            1           1         None
#
#                           address_cleaned    year       suburb
# 0           39 FILS​ON STRΕΕT, ASCOT VALE  2019.0   ASCOT VALE
# 1           39 FILS​ON STRΕΕT, ASCOT VALE  2017.0   ASCOT VALE
# 2           39 FILS​ON STRΕΕT, ASCOT VALE  2014.0   ASCOT VALE
# 3           39 FILS​ON STRΕΕT, ASCOT VALE  2014.0   ASCOT VALE
# 4           39 FILS​ON STRΕΕT, ASCOT VALE  2007.0   ASCOT VALE
# ...                                   ...     ...          ...
# 517107        63 ALBENCA STREET, MΕNTОNΕ   2011.0     MΕNTОNΕ
# 517108        63 ALBENCA STREET, MΕNTОNΕ   2011.0     MΕNTОNΕ
# 517109         13​ LОԌΑN СОՍRT , MΕNTОNΕ   2018.0     MΕNTОNΕ
# 517110         13​ LОԌΑN СОՍRT , MΕNTОNΕ   2018.0     MΕNTОNΕ
# 517111  ​3/42 ​FLINDERS STREET​ , MENTONE     NaN      MENTONE
#
# [517112 rows x 12 columns]

# %%
create_dir("../data/raw/oldlistings_buy/")
final_expanded_df.to_csv("../data/raw/oldlistings_buy/oldlistings_buy_5.csv", index=False)
# Out:
# Directory already exists: ../data/raw/oldlistings_buy/
